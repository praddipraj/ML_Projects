# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
data=pd.read_csv("titanicdataset.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.countplot(x='Survived',hue='Sex',data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Pclass',data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
data['Age'].hist().plot()
# Out:
# []

# %%
data['Pclass'].hist().plot()
# Out:
# []

# %%
sns.boxplot(x='Pclass',y='Age',data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sex=pd.get_dummies(data['Sex'],drop_first=True)
sex = sex.astype(int)

pclass=pd.get_dummies(data['Pclass'],drop_first=True)
pclass = pclass.astype(int)

Embark=pd.get_dummies(data['Embarked'],drop_first=True)
Embark = Embark.astype(int)


data=pd.concat([data,sex,pclass,Embark],axis=1)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop(['Name','PassengerId','Pclass','Sex','Embarked','Ticket'],axis=1,inplace=True)
print(data)
# Out:
#      Survived   Age  SibSp  Parch     Fare Cabin  male  2  3  Q  S
# 0           0  22.0      1      0   7.2500   NaN     1  0  1  0  1
# 1           1  38.0      1      0  71.2833   C85     0  0  0  0  0
# 2           1  26.0      0      0   7.9250   NaN     0  0  1  0  1
# 3           1  35.0      1      0  53.1000  C123     0  0  0  0  1
# 4           0  35.0      0      0   8.0500   NaN     1  0  1  0  1
# ..        ...   ...    ...    ...      ...   ...   ... .. .. .. ..
# 886         0  27.0      0      0  13.0000   NaN     1  1  0  0  1
# 887         1  19.0      0      0  30.0000   B42     0  0  0  0  1
# 888         0   NaN      1      2  23.4500   NaN     0  0  1  0  1
# 889         1  26.0      0      0  30.0000  C148     1  0  0  0  0
# 890         0  32.0      0      0   7.7500   NaN     1  0  1  1  0
#
# [891 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# Survived      0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# male          0
# 2             0
# 3             0
# Q             0
# S             0
# dtype: int64

# %%
data['Age'].fillna(-1,inplace=True)
data.isnull().sum()
# Out:
# Survived      0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# male          0
# 2             0
# 3             0
# Q             0
# S             0
# dtype: int64

# %%
data=data.drop('Cabin',axis=1)

# %%
data
# Out:
#      Survived   Age  SibSp  Parch     Fare  male  2  3  Q  S
# 0           0  22.0      1      0   7.2500     1  0  1  0  1
# 1           1  38.0      1      0  71.2833     0  0  0  0  0
# 2           1  26.0      0      0   7.9250     0  0  1  0  1
# 3           1  35.0      1      0  53.1000     0  0  0  0  1
# 4           0  35.0      0      0   8.0500     1  0  1  0  1
# ..        ...   ...    ...    ...      ...   ... .. .. .. ..
# 886         0  27.0      0      0  13.0000     1  1  0  0  1
# 887         1  19.0      0      0  30.0000     0  0  0  0  1
# 888         0  -1.0      1      2  23.4500     0  0  1  0  1
# 889         1  26.0      0      0  30.0000     1  0  0  0  0
# 890         0  32.0      0      0   7.7500     1  0  1  1  0
#
# [891 rows x 10 columns]

# %%
x=data.drop('Survived',axis=1)
y=data['Survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
x_train.columns = x_train.columns.astype(str)

# %%
x_train.columns = x_train.columns.astype(str)
x_test.columns = x_test.columns.astype(str)
model=LogisticRegression(max_iter=100000)
model.fit(x_train,y_train)
prediction=model.predict(x_test)
classification_report(y_test,prediction)
print("Test Accuracy",accuracy_score(y_test,prediction))
print("Test Precision",precision_score(y_test,prediction))
print("Test Recall : ",recall_score(y_test,prediction))
print("Test F1 score : ",f1_score(y_test,prediction))
# Out:
# Test Accuracy 0.7873134328358209
# Test Precision 0.7755102040816326
# Test Recall :  0.6846846846846847
# Test F1 score :  0.7272727272727272

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[135,  22],
#        [ 35,  76]], dtype=int64)

# %%
predictions=model.predict(x_train)
classification_report(y_train,predictions)
print("Test Accuracy",accuracy_score(y_train,predictions))
print("Test Precision",precision_score(y_train,predictions))
print("Test Recall : ",recall_score(y_train,predictions))
print("Test F1 score : ",f1_score(y_train,predictions))
# Out:
# Test Accuracy 0.8105939004815409
# Test Precision 0.7868020304568528
# Test Recall :  0.670995670995671
# Test F1 score :  0.7242990654205608

# %%
confusion_matrix(y_train,predictions)
# Out:
# array([[350,  42],
#        [ 76, 155]], dtype=int64)
